# %%
import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# # Погода в Скопье

# %%
with urllib.request.urlopen('https://yandex.ru/pogoda/10463?') as response:
    html = response.read()
soup = BeautifulSoup(html, 'html.parser')

def scrape_weather():
    temp = -100
    for elem in soup.find("div", { "class" : "fact__temp" }):
        if elem['class'][0] == "temp__value":
            temp = elem.text
    wind_speed = soup.find("span", { "class" : "wind-speed" }).text
    condition = soup.find("div", { "class" : "fact__condition" }).text
    return temp, wind_speed, condition

def get_condition_image(condition_text):
    condition_text = condition_text.lower()
    if 'ясно' in condition_text:
        return fa-sun-o
    elif 'снег' in condition_text:
        return fa-snowflake-o
    elif 'дождь' in condition_text:
        return fa-tint
    else:
        return fa-cloud

temp, wind_speed, condition = scrape_weather()
condition_image = get_condition_image(condition)

# %% [markdown]
# # Дотракийский словарь

# %%
import re
import operator
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
req = urllib.request.Request('http://wiki.dothraki.org/Vocabulary', headers={'User-Agent': 'Mozilla/5.0'})
html = urllib.request.urlopen(req).read()
soup = BeautifulSoup(html, 'html.parser')

# %%
full_regex = re.compile(b"<ul><li><b>(.*)<\/b>.*\\n<\/li><\/ul>\\n<dl><dd><i>(.*)\.<\/i>")

# %%
def clean_pos(pos):
    result = pos.strip()
    result = result.replace(".", "")
    return result

# %%
matches = re.findall(full_regex, html)
data = {}
for word, pos in matches:
    data[word] = clean_pos(pos.decode("utf-8"))

# %%
labels, values = zip(*Counter(data.values()).items())

label_size = 14
plt.rcParams['xtick.labelsize'] = label_size 
indexes = np.arange(len(labels))
width = 1
plt.figure(figsize=(20,10))
plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels, rotation='vertical')
plt.show()

# %%
first_letters = [word.decode("utf-8")[0].lower() for word in data.keys()]

# %%
labels, values = zip(*sorted(Counter(first_letters).items(), key=operator.itemgetter(0)))
label_size = 14
plt.rcParams['xtick.labelsize'] = label_size 
indexes = np.arange(len(labels))
width = 1
plt.figure(figsize=(20,10))
plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels, rotation='vertical')
plt.show()

# %% [markdown]
# # Транслитерация газеты

# %%
from alphabet_detector import AlphabetDetector
ad = AlphabetDetector()

# %%
req = urllib.request.Request('http://vpravda.ru/')
html = urllib.request.urlopen(req).read()
soup = BeautifulSoup(html, 'html.parser')

# %%
text = soup.text.split("\n")

# %%
text = [x for x in text if x != '']

# %%
regex_cyr_word = re.compile("[А-я]+(?:-[А-я]*)*")

# %%
def validate_word(word):
    if regex_cyr_word.match(word):
        if ad.is_cyrillic(word):
            return True
    return False

# %%
def preprocess_text(text):
    result = re.sub('([.,!?()»«])', r' \1 ', text)
    result = re.sub('\s{2,}', ' ', result)
    return result

# %%
def prerevolutionary_form(word):
    result = word + "ъ"
    return result

# %%
words = [word for line in text for word in preprocess_text(line).split() if validate_word(word)]
unique_words = set(words)

# %%
prerevolutionary_words = [prerevolutionary_form(word) for word in unique_words]

# %%
words_freq = Counter(words)

# %%
words_freq.most_common(10)
# Out:
# [('в', 112),
#  ('на', 17),
#  ('с', 15),
#  ('и', 15),
#  ('В', 12),
#  ('Волгограде', 11),
#  ('За', 10),
#  ('из', 9),
#  ('Волгоградской', 9),
#  ('области', 9)]

# %%
for elem in words_freq.most_common(10):
    print(elem[0])
# Out:
# в
# на
# с
# и
# В
# Волгограде
# За
# из
# Волгоградской
# области

# %% [markdown]
# # Дореволюционная орфография

# %%
try:
    from urllib.request import Request, urlopen  # Python 3
except:
    from urllib2 import Request, urlopen  # Python 2
import gzip
    
headers = {'Accept-Encoding':
'gzip, deflate', 'accept': '*/*','User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'}
url = 'http://www.dorev.ru/ru-faq-yatroots.html'
req = Request(url, headers=headers)
with urllib.request.urlopen(req) as response:
    html = response.read()
    if(response.headers['content-encoding'] == 'gzip'):
        html = gzip.decompress(html)

# %%
html.decode("windows-1251")
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n<html>\n<!--\n#######################################################################################\n##   cms4site(TM) SITE CONSTRUCTION AND CONTENT MANAGEMENT SYSTEM 3.6.2\n##   (C)2001-2017 cms4site group ALL RIGHTS RESERVED. 22.12.2017 12:53:10 MSK\n##   127.0.0.2 [www.dorev.ru] 77.21.251.195 [U1: ip4d15fbc3.dynamic.kabel-deutschland.de]\n##   Apache/1.3.42 (Unix) PHP/5.2.17\n##   Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5 [gzip,deflate]\n##   399E6B54F955AB0A:380(795334)0.0042 \n#######################################################################################\n-->\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=windows-1251">\n<meta name="Content-Language" content="ru">\n<meta name="description" content="Употребление буквы ять - FAQ/Статьи - ДОРЕВОЛЮЦИОННАЯ ОРФОГРАФИЯ - Дореволюционный (дореформенный, царский, старый) орфографический словарь - cms4site&#8482;">\n<meta name="keywords" content="буквы употребление также пишется черезъ существительныхъ стоимен словахъ пишутся исключен вать окончан наприм корней значен этихъ шать чить формы содержащ слова производныя которыхъ какъ встр">\n<title>УПОТРЕБЛЕНИЕ БУКВЫ ЯТЬ - ДОРЕВОЛЮЦИОННАЯ ОРФОГРАФИЯ - Дореволюционный (дореформенный, царский, старый) орфографический словарь - cms4site&#8482;</title>\n<!--compressed--><script type="text/javascript" src="xmmscript/xmmscript.php"></script>\n<!--compressed--><link rel="stylesheet" type="text/css" href="xmmscript/xmmstyles.php">\n<link rel="shortcut icon" href="http://www.dorev.ru/favicon.ico" type="image/x-icon">\n</head>\n<body text="#000000" link="#009900" vlink="#007000" alink="#00ff00" bgcolor="#009100" marginwidth=0 marginheight=20 topmargin=20 leftmargin=0 rightmargin=0 bottommargin=20>\n<script>xsetCookie(\'XMMFREE\',\'YES\');function closeadfree() { document.getElementById(\'ADFREE\').style.visibility=\'hidden\'; } if (xgetCookie(\'XMMFREE\')==\'YES\') { document.write(\'<div title="Закрыть" id=\\\'ADFREE\\\' style="position:absolute;right:0;top:0;visibility:;cursor:pointer" onClick="closeadfree()">\');document.write(\'<img src="xmmimages/xmmfree.gif" width=362 height=362></div>\'); } </script><a name="TOP"></a><table width="100%" cellpadding=0 cellspacing=0 border=0>\n<tr valign="top">\n<td bgcolor="#b9bfb9">\n<table width="100%" cellpadding=4 cellspacing=1 border=0>\n<tr valign="top"><!--HEADING-->\n<td bgcolor="#f9fef9"><img src="xmmimages/xmmzdummy.gif" width=40 height=1></td>\n<td width="99%" bgcolor="#f9fef9" align="right"><table cellpadding=0 cellspacing=0 border=0 width="100%"><tr valign="bottom"><td><span style="font-size:72px;color:#AA3300;font-family:Palatino Linotype,Arial Unicode MS,Code2000,Lucida Sans Unicode">&nbsp;&#1123;</span></td><td align=right><img src="xmmimages/xmmzdummy.gif" width=1 height=20><br><a onFocus="this.blur()" title="Начало" HREF="/"><img src="xmmimages/xmmzlogo.gif" hspace=26 vspace=0 border=0><br><nobr><span class="NN"><font color="#666666">cms4site&#8482; система построения сайтов и управления контентом 3.6.2</a><img src="xmmimages/xmmzdummy.gif" width=40 height=1><br><img src="xmmimages/xmmzdummy.gif" width=1 height=1></td></tr></table></td>\n<td bgcolor="#f9fef9"><img src="xmmimages/xmmzdummy.gif" width=40 height=1></td>\n</tr>\n<tr valign="top"><!--TOPMENU-->\n<td bgcolor="#e9eee9"><span class="NN">&nbsp;</td>\n<td bgcolor="#e9eee9"><table border="0" cellpadding="0" cellspacing="0" height="20"><tr><td><img src="xmmimages/xmmzbullet.gif"></td><td><b><a onFocus="this.blur()" title="Дореволюционный (дореформенный, царский, старый) орфографический словарь" href="ru-index.html"><nobr>Дореволюционная орфография</nobr></a><b class="NN">&nbsp;. </b><a onFocus="this.blur()" title="Часто задаваемые вопросы" href="ru-faq.html" class="PARENT"><nobr>FAQ/Статьи</nobr></a><b class="NN">&nbsp;. </b><a onFocus="this.blur()" title="Есть, что сказать?" href="ru-letter.ht ...
